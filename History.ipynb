# %%
history = open('titles.csv', encoding='utf-8')

# %%
history.readline()

# %%
history_dict = dict()
title_dict = dict()

# %%
count = 0
while True:
    title = history.readline()
    
    if title == "":
        print('finish')
        break
    title_dict[count] = title
    count += 1
    for i in title.split():
        history_dict[i] = 0

# %%
count = 0
for i in history_dict.keys():
    history_dict[i] = count
    count += 1

# %%
data = []

# %%
history = open('titles.csv', encoding='utf-8')
history.readline()
count = 0
while True:
    vector = [0]*11048
    title = history.readline()
    if title == "":
        print('finished')
        break
    count += 1
    for i in title.split():
        vector[history_dict[i]] = 1
    data.append(vector)

# %%
import numpy as np
x = np.array([i for i in data])

# %%
def group_assignment(data, centroids):
    grouping_vec_c = np.zeros(len(data))
    for i in range(len(data)):
        dist = np.zeros(len(centroids))
        for j in range(len(centroids)):
            dist[j] = np.linalg.norm(data[i] - centroids[j])
        min_dist = min(dist)
        for j in range(len(centroids)):
            if min_dist == dist[j]:
                grouping_vec_c[i] = j +  1
    return grouping_vec_c

# %%
def update_centroid(data, grouping, centroids):
    new_centroids = []
    for i in range(len(centroids)):
        cent = np.zeros(len(data[0]))
        count = 0
        for j in range(len(data)):
            if grouping[j] == (i+1):
                cent = cent + data[j]
                count += 1
        group_average = cent/count
        new_centroids.append(group_average)
    return new_centroids

# %%
def clustering_objective(data, grouping, centroids):
    J_obj = 0
    for i in range(len(data)):
        for j in range(len(centroids)):
            if grouping[i] == (j+1):
                J_obj += np.linalg.norm(data[i] - centroids[j])
    J_obj = J_obj/len(data)
    return J_obj

# %%
def Kmeans_alg(data, centroids):
    iteration = 0
    J_obj_vector = []
    Stop = False
    while Stop == False:
        grouping = group_assignment(data, centroids)
        new_centroids = update_centroid(data, grouping, centroids)
        J_obj = clustering_objective(data, grouping, new_centroids)
        J_obj_vector.append(J_obj)
        iteration += 1
        if np.linalg.norm(np.array(new_centroids) - np.array(centroids)) < 1e-6:
            Stop = True
        else:
            centroids = new_centroids
    return new_centroids, grouping, J_obj_vector, iteration

# %%
import random
new_centroids, grouping, J_obj_vector, iteration = Kmeans_alg(x, [x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                                     x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)],
                                                              x[random.randint(0, 5000)], 
                                                              x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                  x[random.randint(0, 5000)],
                                                                 ])

# %%
count = 0
for i in range(len(grouping)):
    
    if grouping[i] == count:
        
        print(title_dict[i])
count +=1

# %%
for i in range(len(grouping)):
    
    if grouping[i] == count:
        
        print(title_dict[i])
count +=1
# Out:
# "Quẻ Bói (卜卦 Divination) - Phùng Đề Mạc (冯提莫 Feng Timo) [Vietsub+CC Subtitle] - YouTube"
#
# "(3) Gặp Người Đúng Lúc (剛好遇見你 Gang Hao Yu Jian Ni) - Phùng Đề Mạc (馮提莫 Feng Timo) - YouTube"
#
# "(3) Hồng Chiêu Nguyện (紅昭願 Hong Zhao Yuan) - Phùng Đề Mạc (馮提莫 Feng Timo) - YouTube"
#
# "Nữ Nhi Tình (女儿情 Girl's Love) - Phùng Đề Mạc (馮提莫 Feng Timo) (Vietsub+Engsub) - YouTube"
#
# "Biệt Khúc Chờ Nhau - Phùng Đề Mạc | 情深深雨濛濛 - 冯提莫 [Vietsub] - YouTube"
#
# "Thần Thoại (美丽的神话 Endless Love) - Phùng Đề Mạc (冯提莫 Feng Timo) ft. Jackie Chan (成龙) [CC Subtitle] - YouTube"
#
# "Hồng Nhan Xưa (紅顏舊 Aging of Beauty) - Phùng Đề Mạc (冯提莫 Feng Timo) [Vietsub+Engsub] - YouTube"
#
# "
- Phùng Đề Mạc (冯提莫 Feng Timo) [Vietsub+Engsub] - YouTube"
#
# "Cảm Ơn Vì Đã Yêu (谢谢爱过 Thanks for loving) - Phùng Đề Mạc (冯提莫 Feng Timo) [Vietsub+Engsub] - YouTube"
#
# "(Vietsub) Tay Trái (左手 Left hand) - Phùng Đề Mạc (馮提莫 Feng Timo) - YouTube"
#
# "Người Đến Từ Triều Châu - Phùng Đề Mạc | 爱拼才会赢 - 冯提莫 Feng Timo - YouTube"
#
# "Tiểu Ô Quy (张栋梁 - 小乌龟 Little Turtle) - Phùng Đề Mạc (冯提莫 Feng Timo) Cover [Vietsub+Engsub] - YouTube"
#
# "(Vietsub) Người Em Yêu Chính Là Anh - Phùng Đề Mạc | 爱的就是你 - 馮提莫 - YouTube"
#
# "(Vietsub+Engsub) Phật Hệ Thiếu Nữ (佛系少女 Fu Xi Shao Nu) - Phùng Đề Mạc (Feng Timo 馮提莫) - YouTube"
#
# "(Vietsub+Engsub) I Want To Tell You Baby (我想對你說baby) - Phùng Đề Mạc (Feng Timo 馮提莫) - YouTube"

# %%
for i in range(len(grouping)):
    
    if grouping[i] == count:
        
        print(title_dict[i])
count +=1
# Out:
# "off_1 adverb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "off_2 preposition - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "parable noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "penguin noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "digression noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "bulk_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "vicinity noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "dichotomy noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "archetype noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "apology noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "criterion noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "impression noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "anomaly noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "colloquially adverb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "parlance noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "corral_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wrangle_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "craft_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "slot_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "realtortm noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "partition_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "daemon noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "scaffold noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "scaffolding noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "asynchronously adverb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "conduit noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "spruce_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "house_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "parallelogram noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "rally_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "bore_2 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "member noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "vent_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "echelon noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "cursor noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "displacement noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "litany noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wart noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "impedance noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "hunch_2 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "mortal_2 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "indictment noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "invocation noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "consortium noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "buff_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "coalition noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wag_3 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "waterfall noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "impurity noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "awry adverb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "disdain_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "ceremony noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "sequel noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "referral noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "interlude noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "fork_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "forgery noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "balloon_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "pulse_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "pivot_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "goof_2 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "hegemony noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "worship_1 noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "organism noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "topology noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "analysis noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "ensemble noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "illumination noun - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"

# %%
for i in range(len(grouping)):
    
    if grouping[i] == count:
        
        print(title_dict[i])
count +=1
# Out:
# "vast adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "rigorous adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "oscillate verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "avid adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "off_3 adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "off_5 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "penguine - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "loose_1 adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "assert verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "vacinity - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "robust adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "minor_1 adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "valuable adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "nonchalant adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "naive adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "imitate verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "anomolies - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "fetch verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "rudimentary adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "opt verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wingging - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wing_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "corral_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wrangle_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "craft_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "masquerade_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "peruse verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "partion - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "asynchronous adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "soar verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "spruce_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "spruce-up phrasal verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "house_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "diagonal_1 adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "inject verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "injective - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "sparse adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "rallly - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "tranpose - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "transpose verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "bore_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "atomic adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "unary adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "pertinent adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "dangle verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "vent_2 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "crude_1 adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "sematic - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "semantic adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "emit verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "lossless adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "lossy adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "flush_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "displacêmnt - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "empednace - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "adhere verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "Choropleth - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "hunch_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "tenary - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "ternary - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "alleviate verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "granularity - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "crooked adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "bogus adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "stringent adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "abort verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "tentative adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "prone adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "presume verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "interleave verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "replicate verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wag_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "slip_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "idempotent - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wiggliness - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "wiggly adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "cubersome - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "cumbersome adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "modularity - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "unceremonious adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "halt_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "orthogonal - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "articulate_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "unobtrusive adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "contentious adjective - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "goò - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "goof_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "truncate verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "precarity - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "perceive verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "stir_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "fliding - Did you spell it correctly? Alternative spellings from Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
#
# "fiddle_1 verb - Definition, pictures, pronunciation and usage notes | Oxford Advanced Learner's Dictionary at OxfordLearnersDictionaries.com"
